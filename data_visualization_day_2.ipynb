# %% [markdown]
# ##### import the titanic dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:\\Users\\heena\\Downloads\\titanic (1).csv")

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True  NaN  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN
# 3  woman       False    C  Southampton   yes  False          NaN
# 4    man        True  NaN  Southampton    no   True          NaN

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the fare of class.

# %%
### code here
plt.figure(figsize=(5,5))
sns.barplot(data=data,y="fare",x="class",hue="sex")
plt.show()

# %% [markdown]
# we can see clearly in the above plot that average fare of first_class including male and female is very high
# around 110 is for male and around 65 is for female
# fare for class_third is very less as it ranges between 0-15 both for male and female

# %% [markdown]
# ###### 2. Write a Python program to display a horizontal bar chart of the fare of class.

# %%
### code here
plt.figure(figsize=(5,5))
sns.barplot(data=data,x="fare",y="class",hue="sex",palette="autumn")
plt.show()

# %% [markdown]
# ###### 3. Write a Python program to display a bar chart of the fare of class. Use different color for each bar.

# %%
### code here
plt.figure(figsize=(5,5))
sns.barplot(data=data,x="class",y="fare")
plt.show()

# %% [markdown]
# fare of first class is maximum ie above 80 where as fare of second class is around 20
# fare of third class is very less is around 15

# %% [markdown]
# ###### 4. Write a Python program to create a pie chart of the fare of class.

# %%
### code here
data.groupby(["class"]).sum().plot(kind="pie",y="fare",autopct="%0.0f%%")
# Out:
# <AxesSubplot:ylabel='fare'>

# %% [markdown]
# fare of 1st class is maximum as compared to second and third class

# %% [markdown]
# ######5. Write a Python program to display a count plot of all categorical columns.

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'Unnamed: 15'],
#       dtype='object')

# %%
df=data[["sex","embarked","class","who","adult_male","deck",'embark_town',"alive","alone"]]

# %%
m=sns.FacetGrid(data=df,hue="class",size=3)
m.map(sns.countplot,"alive").add_legend()

# %% [markdown]
# more than 350 people are alive and around 120 people are died in the tragedy in the third class
# in second_class more people are died as compared to alive
# In the first class_people more than 125 are alive,and there is no information regarding death of first_class people

# %%
### code here
m=sns.FacetGrid(data=df,hue="embark_town",size=3,palette="CMRmap_r")
m.map(sns.countplot,"who")
m.add_legend()

# %% [markdown]
# in titanic ship maximum or more than 400 people are men from southampton,min men are from Queenstown and ,above min there are
# arund 70 men are from Cherbourg
# more children are from southampton and min children are from Queenstown
# In the titanic ship more momen are from Cherboug,remaining from Queenstown
# with the above plot we can conculde In the ship more passengers are from Southampton city are men

# %% [markdown]
# ###### 6. Write a Python program to display a factor plot of ( pclass vs embarked). hist (kind = 'count')

# %%
  #### code here
plt.figure(figsize=(10,2))
sns.factorplot(data=data,x="pclass",hue="embarked",kind="count")
plt.show()

# %% [markdown]
# in the above plot we can see that,more people are from southampton city are in pclass 3
# ship has very less people from Queenstown and  max of those people are categorised into pclass 3,
# more people from cherbourg come under pclass 1, pclass 3 and pclass 2 respectively

# %%
sns.factorplot(data=data,x="embarked",kind="count",hue="pclass")

# %% [markdown]
# in the above plot we can see that,more people are from southampton city are in pclass 3
# ship has very less people from Queenstown and max of those people are categorised into pclass 3,
# more people from cherbourg come under pclass 1, pclass 3 and pclass 2 respectively

# %% [markdown]
# ###### 7. Write a Python programming to display a factor plot of ( pclass vs sex). hist (kind = 'count')

# %%
### code here

sns.factorplot(data=data,x="pclass",hue="sex",kind="count")
plt.show()

# %% [markdown]
# more people(male and female)are from pclass 3, less people are female from pclass 2

# %% [markdown]
# ###### 8. Write a Python programming to display a factor plot of ( embarked vs sex). hist (kind = 'count')

# %%
### code here 
sns.factorplot(data=data,x="embarked",hue="sex",kind="count",palette='prism')
plt.show()

# %% [markdown]
# ###### 9. Write a Python program to display distribution plot for all numberical columns.

# %%
### code here
m=sns.FacetGrid(data=data,hue="sex",size=5)
m.map(sns.distplot,"survived").add_legend()

# %% [markdown]
# in the above plot we can see that less people are survived  as compared to death
# density of death is high,death rate of male is high as compared to female

# %% [markdown]
# ###### 10. Write a Python program to display boxplot of age, pclass and hue = gender.

# %%
### code here

# %%
sns.boxplot(data=data,x="pclass",y="age",hue="sex")
plt.show()

# %% [markdown]
# more passengers are from pclass-1 having age between 30 t0 50 ie IQR is 20 max age=80
# female passengers from pclass-1 are having age of between 25 to 45, max age is 65,in pclass-1 there are no outliers
#
# in pclass-2 more people(male and female) passengers are having age ranging from 25 to 35,but males have more upper extreme values
# and female has no lower extreme values,
# in pclass-3 ,male passenger have more upper extreme values as compared to lower outliers,and females have no outliers
#
# from the above plot we can conclude that,more outliers are from pclass-3 males,

# %% [markdown]
# ##### Bonus Question

# %% [markdown]
# ##### 1. What are the plots we can create on numerical columns.

# %%
### write here
1.distplot
2.ecdfplot
3.rug plot
4.joint plot
5.pair plot
6.heat map
7.bar plot
8.box plot

# %% [markdown]
# ###### 2. What are the plots we can create on categorical columns.

# %%
### write here

# %%
1. scatter plot
2. bar graph
3. box plot
4. count plot
5. swarm plot
6. violin plot
7. stripplot
