# %% [markdown]
# ##### import the Diamond dataset

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\heena\\Downloads\\diamonds.csv")

# %% [markdown]
# ###### 1. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
data.shape
# Out:
# (53940, 11)

# %%
### code here
data.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
data.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %% [markdown]
# ##### 2. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
### code here
data[["color","cut","clarity"]].describe()
# Out:
#         color    cut clarity
# count   53940  53940   53940
# unique      7      5       8
# top         G  Ideal     SI1
# freq    11292  21551   13065

# %%
data.describe(include="object")
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ###### 3. Write a Pandas program to remove the second column of the diamonds Dataframe. (don't use original dataset)

# %%
### code here
df=pd.read_csv("C:\\Users\\heena\\Downloads\\diamonds.csv")
del df["carat"]
df
# Out:
#        Unnamed: 0        cut color clarity  depth  table  price     x     y  \
# 0               1      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1               2    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2               3       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3               4    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4               5       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935       53936      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936       53937       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937       53938  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938       53939    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ###### 4. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe. (dont use original dataset)

# %%
### code here
df.drop([2,5,8,11])
# Out:
#        Unnamed: 0        cut color clarity  depth  table  price     x     y  \
# 0               1      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1               2    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3               4    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4               5       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 6               7  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935       53936      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936       53937       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937       53938  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938       53939    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 3      2.63
# 4      2.75
# 6      2.47
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53936 rows x 10 columns]

# %% [markdown]
# ###### 5. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
### code here
data.cut.sort_values(ascending=True)
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# ###### 6. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
### code here
data.sort_values("carat",ascending=True)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0    367   3.81
# 31597       31598   0.20    Ideal     D     VS2   61.5   57.0    367   3.81
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
# 31595       31596   0.20    Ideal     E     VS2   59.7   55.0    367   3.86
# 31594       31595   0.20  Premium     E     VS2   59.7   62.0    367   3.84
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z
# 31593   3.78  2.32
# 31597   3.77  2.33
# 31596   3.71  2.33
# 31595   3.84  2.30
# 31594   3.80  2.28
# ...      ...   ...
# 25999   9.94  6.24
# 25998  10.10  6.17
# 27130   9.85  6.43
# 27630  10.16  6.72
# 27415  10.54  6.98
#
# [53940 rows x 11 columns]

# %%
data.sort_values("carat",ascending=False)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0    367   3.81
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0    367   3.79
# 31601       31602   0.20  Premium     D     VS2   61.7   60.0    367   3.77
# 14             15   0.20  Premium     E     SI2   60.2   62.0    345   3.79
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
#
#            y     z
# 27415  10.54  6.98
# 27630  10.16  6.72
# 27130   9.85  6.43
# 25999   9.94  6.24
# 25998  10.10  6.17
# ...      ...   ...
# 31592   3.78  2.24
# 31591   3.77  2.26
# 31601   3.72  2.31
# 14      3.75  2.27
# 31596   3.71  2.33
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
#### code here
data[data["carat"]>=0.3]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16             17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 4      4.35  2.75
# 10     4.28  2.73
# 13     4.37  2.71
# 15     4.42  2.68
# 16     4.34  2.68
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [52341 rows x 11 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
### code here
data[(data["x"]>5) & (data["y"]>5) & (data["z"]>5)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 11778       11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34
# 13002       13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74
# 13118       13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01
# 13562       13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59
# 13757       13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
# 49905       49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01
#
#            y      z
# 11778   7.28   5.12
# 13002   7.70   5.36
# 13118   7.95   5.23
# 13562   7.56   5.04
# 13757   8.02   5.36
# ...      ...    ...
# 27748   7.97   5.04
# 27749   8.47   5.16
# 48410   5.15  31.80
# 49189  31.80   5.12
# 49905   5.04   5.06
#
# [1457 rows x 11 columns]

# %% [markdown]
# ###### 9. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
### code here
data.mean(axis=1)
# Out:
# C:\Users\heena\AppData\Local\Temp\ipykernel_8160\656784734.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=1)
# 0          56.76125
# 1          57.38125
# 2          57.82000
# 3          58.71875
# 4          59.13125
#             ...
# 53935    7103.31625
# 53936    7103.48375
# 53937    7104.17500
# 53938    7103.98375
# 53939    7103.78625
# Length: 53940, dtype: float64

# %% [markdown]
# ###### 10. Write a Pandas program to calculate the mean of price for each cut  and find maximum top 3 of diamonds DataFrame.

# %%
#### code here
data.price.mean()
# Out:
# 3932.799721913237

# %%
data.price.sort_values().tail(3)
# Out:
# 27747    18806
# 27748    18818
# 27749    18823
# Name: price, dtype: int64

# %%
data["price"].max()
# Out:
# 18823

# %% [markdown]
# ##### 11. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
### code here
data.price.count(),data.price.max(),data.price.min()
# Out:
# (53940, 18823, 326)

# %% [markdown]
# ###### 12. Write a Pandas program to display and count the unique values in cut series of diamonds DataFrame.

# %%
### code here
data.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ######13.  Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
### code here
data.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# ###### 14. Write a Pandas program to calculate the multiply of x, y and z for each cut of diamonds DataFrame.

# %%
### code here
data["x"]*data["y"]*data["z"]
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Length: 53940, dtype: float64

# %% [markdown]
# ##### 15. Write a Pandas program to read rows 0 through 2 (inclusive), columns ‘color’ and ‘price’ of diamonds DataFrame.

# %%
## code here
data.loc[0:2,["color","price"]]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# ###### 16. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
### code here
data.iloc[0:2,0:4]
# Out:
#    Unnamed: 0  carat      cut color
# 0           1   0.23    Ideal     E
# 1           2   0.21  Premium     E

# %% [markdown]
# ##### 17. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
### code here
data.sample(10)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 32010       32011   0.31      Ideal     D    VVS2   61.9   55.0    777  4.36
# 32548       32549   0.27      Ideal     D    VVS2   62.3   57.0    799  4.15
# 49339       49340   0.81  Very Good     G     SI2   63.2   60.0   2095  5.82
# 28336       28337   0.33    Premium     G     VS1   61.9   59.0    666  4.43
# 38421       38422   0.30    Premium     E      IF   61.0   59.0   1026  4.29
# 32019       32020   0.31  Very Good     G    VVS1   58.8   59.0    778  4.44
# 1770         1771   0.91    Premium     G     SI2   62.8   59.0   3047  6.14
# 26666       26667   1.52  Very Good     E     VS1   62.4   55.0  16485  7.33
# 18608       18609   1.00    Premium     G    VVS2   59.5   61.0   7589  6.46
# 9631         9632   1.21       Fair     G     SI1   64.5   56.0   4637  6.69
#
#           y     z
# 32010  4.39  2.71
# 32548  4.13  2.58
# 49339  5.79  3.67
# 28336  4.45  2.75
# 38421  4.33  2.63
# 32019  4.47  2.62
# 1770   6.12  3.85
# 26666  7.41  4.60
# 18608  6.42  3.83
# 9631   6.62  4.29

# %% [markdown]
# ###### 18. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
l=len(data)
l
# Out:
# 53940

# %%
d=75/100*(len(data))
d
# Out:
# 40455.0

# %%
d75=data.loc[:d,::]
d75
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 0               1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23     Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31     Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...      ...   ...     ...    ...    ...    ...   ...
# 40451       40452   0.76     Fair     H      I1   64.5   57.0   1140  5.79
# 40452       40453   0.31    Ideal     F    VVS1   60.7   57.0   1140  4.41
# 40453       40454   0.31    Ideal     F    VVS1   60.6   56.0   1140  4.44
# 40454       40455   0.32    Ideal     E    VVS1   61.5   56.0   1140  4.43
# 40455       40456   0.50    Ideal     H     SI1   62.2   57.0   1140  5.07
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 40451  5.76  3.73
# 40452  4.39  2.67
# 40453  4.41  2.68
# 40454  4.45  2.73
# 40455  5.09  3.16
#
# [40456 rows x 11 columns]

# %%
### code here
d25=data.loc[d+1:,::]
d25
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 40456       40457   0.50      Ideal     H     SI1   62.4   56.0   1140  5.07
# 40457       40458   0.50      Ideal     H     SI1   62.1   58.0   1140  5.04
# 40458       40459   0.50      Ideal     H     SI1   62.5   57.0   1140  5.06
# 40459       40460   0.50      Ideal     H     SI1   62.0   56.0   1140  5.08
# 40460       40461   0.53       Good     E     SI2   57.9   58.0   1140  5.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 40456  5.09  3.17
# 40457  5.07  3.14
# 40458  5.08  3.17
# 40459  5.11  3.16
# 40460  5.39  3.11
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [13484 rows x 11 columns]

# %% [markdown]
# ###### 19. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
#### code here
data[data.color.duplicated()]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 1      3.84  2.31
# 2      4.07  2.31
# 5      3.96  2.48
# 6      3.98  2.47
# 8      3.78  2.49
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53933 rows x 11 columns]

# %% [markdown]
# ###### 20. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
#### code here
data.color.duplicated().sum()
# Out:
# 53933

# %%
data.duplicated().count()
# Out:
# 53940
